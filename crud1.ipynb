# %%
for i in range(5):
  numbers = list(map(int, input("Enter numbers separated by space: ").split()))
  print("List:", numbers)
# Out:
# Enter numbers separated by space:  6
# List: [6]
# Enter numbers separated by space:  7
# List: [7]
# Enter numbers separated by space:  8
# List: [8]
# Enter numbers separated by space:  9
# List: [9]
# Enter numbers separated by space:  9
# List: [9]

# %%
n = int(input("Enter the number of elements: "))
user_list = []
for i in range(n):
   element = input(f"Enter element {i+1}: ")
   user_list.append(element)
print("List:", user_list)
# Out:
# Enter the number of elements:  4
# Enter element 1:  5
# Enter element 2:  6
# Enter element 3:  7
# Enter element 4:  8
# List: ['5', '6', '7', '8']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
print(list1)
# Out:
# ['anjali', 'bhavya', 'Nihansh', 'Vihansh']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
list1.append("k")
print(list1)
# Out:
# ['anjali', 'bhavya', 'Nihansh', 'Vihansh', 'k']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh","k"]
list1.remove("k")
print(list1)
# Out:
# ['anjali', 'bhavya', 'Nihansh', 'Vihansh']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
list1.insert(0,"b")
print(list1)
# Out:
# ['b', 'anjali', 'bhavya', 'Nihansh', 'Vihansh']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]


print(list1[3])
# Out:
# Vihansh

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
l=list1[0:2]
print(l)
# Out:
# ['anjali', 'bhavya']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
list1[list1.index("bhavya")]="b"
print(list1)
# Out:
# ['anjali', 'b', 'Nihansh', 'Vihansh']

# %%
list1=["anjali","bhavya","Nihansh","Vihansh"]
list1.pop(0)
print(list1)
# Out:
# ['bhavya', 'Nihansh', 'Vihansh']
